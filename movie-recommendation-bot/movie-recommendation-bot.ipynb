# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})

    print(f"[AI]: {message}")

# %%
while True:
    message = input("Send a message: ")

    if message == "exit" or message == "quit" or message == "q":
        break

    else:
        messages.append({"role": "user", "content": message})
        print(f"[USER]: {message}")

        call_ai()
# Out:
# [USER]: 나는 SF 영화를 좋아해
# [AI]: 멋져요! SF 영화 좋아하신다니 저도 반가워요. 분위기나 취향에 따라 맞춤 추천도 가능하니, 원하시는 게 있으면 말해 주세요. 우선 여러 가지 분위기에 어울리는 추천 목록을 간단히 정리해봤어요.
#
# - 입문용/가볍게 즐기기 좋은 것
#   - WALL-E (2008): 귀엽고 따뜻한 휴먼 SF, 환경 메시지까지 담긴 가족 영화처럼 편하게 보기 좋아요.
#   - The Matrix (1999): 액션과 철학이 잘 어우러진 클래식, 한 번 보면 대화거리도 많죠.
#
# - 분위기/연출이 돋보이는 고전-현대 섞인 명작
#   - 2001: A Space Odyssey (1968): 시각적 실험과 의문을 남기는 느리고도 압도적인 체험.
#   - Blade Runner (1982) + Blade Runner 2049 (2017): 질감과 세계관, 인간성과 정체성에 대한 성찰.
#
# - 지적이고 사유를 자극하는 작품
#   - Arrival (2016): 외계인과의 소통이 핵심인 감성적 SF, 휴먼한 메시지.
#   - Ex Machina (2014): 인공지능과 인간 관계를 냉소적이면서도 날카롭게 그린 심리 스릴러.
#
# - 우주 모험과 인간 드라마를 함께
#   - Interstellar (2014): 가족과 과학의 만남, 우주여행의 서사적 스케일이 큼.
#   - The Martian (2015): 현실적인 우주 생존기, 웃음과 긴장을 함께 느낄 수 있어요.
#
# - 하드 SF/저예산의 매력
#   - Moon (2009): 고독한 인물 중심의 저예산 하드 SF의 정수.
#   - Primer (2004) 또는 Coherence (2013): 시간여행/다중우주를 다루는 독립 영화의 매력.
#
# - 애니메이션으로 보는 SF
#   - Akira (1988): 사이버펑크의 정수, 강렬한 영상미와 사회적 주제.
#   - Your Name (2016) 또는 Ghost in the Shell (1995): 시간과 정체성에 관한 이야기.
#
# 원하신다면 이 중에서 분위기별로 3편 정도로 맞춰 1주일 간의 관람 플랜도 짜 드릴게요. 또는 최근 본 영화나 좋아하는 감독, 선호하는 분위기(느림/빠름, 어둡고 진지한지, 가족 친화적인지 등)가 있으면 알려 주세요. 맞춤 추천 리스트를 바로 만들어 드릴게요.
# [USER]: 인셉션이랑 인터스텔라는 이미 봤어
# [AI]: 좋아요. 인셉션과 인터스텔라를 이미 보셨으니, 비슷한 분위기보단 다른 느낌의 재밌는 SF도 같이 추천드릴게요. 취향에 맞춰 더 정교하게 맞춰 드리려면 선호를 좀 알려 주세요. 예를 들어 느리게 생각하게 만드는 철학적 SF를 좋아하나요, 아니면 분위기 있는 비주얼/세계관 위주가 좋나요?
#
# 추천 리스트 (다양한 분위기별로 골랐어요)
#
# - 분위기와 세계관이 돋보이는 명작
#   - 2001: A Space Odyssey (1968) — 시각적 실험과 우주에 대한 철학적 의문을 느끼게 하는 고전.
#   - Blade Runner (1982) — 분위기와 세계관의 정수. 인간성과 정체성에 대한 성찰.
#   - Blade Runner 2049 (2017) — 1편의 세계관을 현대적으로 확장, 시각과 이야기의 깊이가 큼.
#   - Solaris (1972) 또는 Solaris (2002) — 인간 심리와 타자와의 만남을 심도 있게 다룸.
#
# - 지적 자극/철학적 SF
#   - Arrival (2016) — 외계인과의 소통을 통해 언어와 시간에 대한 생각을 이끕니다.
#   - Ex Machina (2014) — 인공지능과 인간 관계를 냉정하고 날카롭게 탐구.
#   - Annihilation (2018) — 생물다양성과 생태학적 불가사의를 미스터리하게 풀어나감.
#
# - 하드 SF/저예산의 매력
#   - Moon (2009) — 고독한 공간에서의 인간성 탐구, 저예산으로도 강력한 몰입감.
#   - Primer (2004) — 시간여행의 복잡한 구조를 독립영화 수준으로 설계한 걸작.
#   - Coherence (2013) — 독립 영화로도 가능한 다중우주/정체성 주제의 심리 스릴러.
#
# - 우주 모험과 인간 드라마
#   - The Martian (2015) — 현실적인 우주 생존기와 유머가 조화롭게 어우러짐.
#   - Gravity (2013) — 우주 공간에서의 생존+고립감을 강렬하게 전달.
#   - Ad Astra (2019) — 우주여행과 가족 이야기가 결합된 느긋한 탐험물.
#
# - 애니메이션으로 보는 SF
#   - Akira (1988) — 사이버펑크의 정수, 강렬한 영상과 사회적 주제.
#   - Ghost in the Shell (1995) — 정체성, 의식과 기술의 경계에 대한 고전적 논의.
#   - Your Name (2016) — 시간성과 정체성에 관한 감성적 SF 애니메이션.
#
# - 분위기 다크/사회적 메시지
#   - Children of Men (2006) — 인류의 미래를 다층적으로 그리는 강력한 디스토피아.
#   - Snowpiercer (2013) — 계급과 사회구조를 우주적 배경 없이도 강렬하게 풍자.
#
# 선호 반영 요청
# - 어떤 분위기를 더 원하나요? (느리지만 깊은 철학적 이야기, 시각적으로 화려한 세계관, 긴장감 있는 심리 스릴러 등)
# - 최근에 본 영화나 피하게 싶은 분위기가 있나요? (예: 너무 어둡거나 잔혹한 것 피하기)
# - 시청 가능 시간대나 자막/더빙 선호가 있나요?
#
# 원하신다면 이 중에서 분위기별로 3편 정도로 골라 1주일 간의 관람 플랜도 바로 만들어 드릴게요. 예를 들어 "월: Arrival, 수: Moon, 토: Blade Runner 2049"처럼 구성해 드릴 수 있어요.
# [USER]: 오늘 밤에 뭐 볼지 추천해 줄래?
# [AI]: 좋아요! 오늘 밤 picks 세 가지로 간단히 추천해볼게요. 분위기나 시간에 따라 골라 보세요.
#
# 1) Arrival (2016) — 1h56m
# - 분위기: 지적이고 감성적인 SF. 외계인과의 소통을 통해 언어와 시간에 대해 생각하게 만드는 이야기.
# - 왜 추천: 단단한 주제와 인간미가 잘 어우러져 밤에 천천히 곱씹으며 보기에 좋아요.
#
# 2) Moon (2009) — 1h37m
# - 분위기: 고독한 하드 SF. 한 명의 배우가 이끄는 저예산 독립영화의 집중력.
# - 왜 추천: 주인공의 심리와 정체성에 집중하는 몰입감이 강하고, 짧은 시간 안에 강한 여운을 남겨요.
#
# 3) Annihilation (2018) — 1h55m
# - 분위기: 미스터리/생태학적 SF. 생태계의 불가사의를 미스터리하게 풀어가는 느낌.
# - 왜 추천: 시각적으로도 독특하고, 담담한 톤에서 점점 긴장감이 올라오는 재미가 있어요.
#
# 선호에 따라 더 맞춰 드릴 수 있어요
# - 느리면서도 사유를 자극하는 걸 원하나요, 아니면 긴장감 있는 심리 스릴러 쪽이 좋나요?
# - 한 편만 볼까요, 아니면 가볍게 두 편 정도의 소소한 더빙/자막 설정으로 마무리할까요?
# - 지금 사용할 스트리밍 서비스나 플랫폼이 있나요? (예: 넷플릭스/왓챠/디즈니플러스 등)
#
# 원하시는 분위기나 시간대를 알려주면 바로 좀 더 구체적으로 1편 추천 플랜도 만들어 드릴게요.
# [USER]: 내가 좋아하는 장르랑 이미 본 영화가 뭐라고 했지?
# [AI]: 요약해 드릴게요:
#
# - 좋아하는 장르: SF 영화
# - 이미 본 영화: Inception(인셉션), Interstellar(인터스텔라)
#
# 필요하시면 이 정보를 바탕으로 더 맞춤형 추천도 바로 드릴게요. 어떤 분위기를 더 원하나요? 느리게 생각하게 하는 철학적 SF, 아니면 시각적 세계관이 멋진 작품, 아니면 긴장감 있는 심리 스릴러 쪽이 좋나요?
